# %% [markdown]
# ** 2.6 Q学習で迷路を攻略 **

# %% [markdown]
# # 使用するパッケージの宣言

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 初期位置での迷路の様子

# %%
# 図を描く大きさと、図の変数名を宣言
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 赤い壁を描く
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 状態を示す文字S0～S8を描く
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 描画範囲の設定と目盛りを消す設定
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom='off', top='off',
                labelbottom='off', right='off', left='off', labelleft='off')

# 現在地S0に緑丸を描画する
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)
# Out:
# /home/toshinao/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %% [markdown]
# # 初期の方策を決定するパラメータtheta_0を設定

# %%
# 行は状態0～7、列は移動方向で↑、→、↓、←を表す
theta_0 = np.array([[np.nan, 1, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1],  # s1
                    [np.nan, np.nan, 1, 1],  # s2
                    [1, 1, 1, np.nan],  # s3
                    [np.nan, np.nan, 1, 1],  # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],  # s7、※s8はゴールなので、方策はなし
                    ])

# %% [markdown]
# # 方策パラメータtheta_0をランダム方策piに変換する関数の定義

# %%
def simple_convert_into_pi_from_theta(theta):
    '''単純に割合を計算する'''

    [m, n] = theta.shape  # thetaの行列サイズを取得
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])  # 割合の計算

    pi = np.nan_to_num(pi)  # nanを0に変換

    return pi

# ランダム行動方策pi_0を求める
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %% [markdown]
# # 初期の行動価値関数Qを設定

# %%
[a, b] = theta_0.shape  # 行と列の数をa, bに格納
Q = np.random.rand(a, b) * theta_0 * 0.1
# *theta0をすることで要素ごとに掛け算をし、Qの壁方向の値がnanになる

# %% [markdown]
# # ε-greedy法を実装

# %%
def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]

    # 行動を決める
    if np.random.rand() < epsilon:
        # εの確率でランダムに動く
        next_direction = np.random.choice(direction, p=pi_0[s, :])
    else:
        # Qの最大値の行動を採用する
        next_direction = direction[np.nanargmax(Q[s, :])]

    # 行動をindexに
    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3

    return action

# %% [markdown]
# ## 番号で表されたactionをノードに変換。引数5個あるが最初のふたつ（s,a)しか使っていない

# %%
def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a]  # 行動aの方向

    # 行動から次の状態を決める
    if next_direction == "up":
        s_next = s - 3  # 上に移動するときは状態の数字が3小さくなる
    elif next_direction == "right":
        s_next = s + 1  # 右に移動するときは状態の数字が1大きくなる
    elif next_direction == "down":
        s_next = s + 3  # 下に移動するときは状態の数字が3大きくなる
    elif next_direction == "left":
        s_next = s - 1  # 左に移動するときは状態の数字が1小さくなる

    return s_next

# %% [markdown]
# ## subsandbox

# %%
Q = np.random.rand(a, b) * theta_0 * 0.1

action = get_action(3, Q , epsilon , pi_0)
print(action)
# Out:
# 2

# %%
epsilon
# Out:
# 3.944304526105059e-31

# %%
get_s_next(0 , action , "meaningless" , "inputs" , "here")
# Out:
# -3

# %%
Q
# Out:
# array([[       nan, 0.00870867, 0.06907827,        nan],
#        [       nan, 0.02045549,        nan, 0.08692077],
#        [       nan,        nan, 0.04094124, 0.03716102],
#        [0.04298617, 0.08022878, 0.05195599,        nan],
#        [       nan,        nan, 0.0457183 , 0.0670113 ],
#        [0.05960136,        nan,        nan,        nan],
#        [0.06632814,        nan,        nan,        nan],
#        [0.01734132, 0.02122782,        nan,        nan]])

# %% [markdown]
# # Q学習による行動価値関数Qの更新

# %% [markdown]
# - a_nextを引数として持たないのがポイント
# - ただし、s_nextは使っている

# %% [markdown]
# **（pythonの関数は基本参照渡しであることに注意） **
#
# ただし、変更されてしまうかどうかは型依存らしい・・・
# http://amacbee.hatenablog.com/entry/2016/12/07/004510

# %%
def Q_learning(s, a, r, s_next, Q, eta, gamma):

    if s_next == 8:  # ゴールした場合
        Q[s, a] = Q[s, a] + eta * (r - Q[s, a])

    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * np.nanmax(Q[s_next,: ]) - Q[s, a])

    return Q

# %% [markdown]
# ## subsandbox

# %%
def reward(s_next):
    if s_next == 8:
        return 1
    else:
        return 0

# %%
s = 0

# %%
Q = np.random.rand(a, b) * theta_0 * 0.1

# %%
epsilon = 0.5

# %%
action = get_action(s, Q , epsilon , pi_0)
print("next action is {} ".format(action))

s_next = get_s_next(0 , action , "meaningless" , "inputs" , "here")
print("next state is {}".format(s_next))
# Out:
# next action is 2
# next state is 3

# %%
gamma
# Out:
# 0.9

# %% [markdown]
# ### （参照渡しなため）Q_learningをQで受けなくても引数がQなだけでQは更新されてしまうことに注意

# %%
Qold = Q.copy()

# %%
Q_learning(s, action, reward(s_next), s_next, Q, eta, gamma)
# Out:
# array([[       nan, 0.08719594, 0.06734074,        nan],
#        [       nan, 0.02627033,        nan, 0.08208485],
#        [       nan,        nan, 0.05900419, 0.09247455],
#        [0.01369089, 0.06638679, 0.04283805,        nan],
#        [       nan,        nan, 0.0982445 , 0.02311464],
#        [0.05701678,        nan,        nan,        nan],
#        [0.09098308,        nan,        nan,        nan],
#        [0.05934305, 0.04537129,        nan,        nan]])

# %%
Q - Qold
# Out:
# array([[        nan,  0.        , -0.00084363,         nan],
#        [        nan,  0.        ,         nan,  0.        ],
#        [        nan,         nan,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,         nan],
#        [        nan,         nan,  0.        ,  0.        ],
#        [ 0.        ,         nan,         nan,         nan],
#        [ 0.        ,         nan,         nan,         nan],
#        [ 0.        ,  0.        ,         nan,         nan]])

# %% [markdown]
# # Q学習で迷路を解く関数の定義、状態と行動の履歴および更新したQを出力

# %%
def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi):
    s = 0  # スタート地点
    a = a_next = get_action(s, Q, epsilon, pi)  # 初期の行動
    s_a_history = [[0, np.nan]]  # エージェントの移動を記録するリスト

    while (1):  # ゴールするまでループ
        a = a_next  # 行動更新

        s_a_history[-1][1] = a
        # 現在の状態（つまり一番最後なのでindex=-1）に行動を代入

        s_next = get_s_next(s, a, Q, epsilon, pi)
        # 次の状態を格納

        s_a_history.append([s_next, np.nan])
        # 次の状態を代入。行動はまだ分からないのでnanにしておく

        # 報酬を与え,　次の行動を求めます
        if s_next == 8:
            r = 1  # ゴールにたどり着いたなら報酬を与える
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            # 次の行動a_nextを求めます。

        # 価値関数を更新
        Q = Q_learning(s, a, r, s_next, Q, eta, gamma)

        # 終了判定
        if s_next == 8:  # ゴール地点なら終了
            break
        else:
            s = s_next

    return [s_a_history, Q]

# %% [markdown]
# # Q学習で迷路を解く

# %%
eta = 0.1  # 学習率
gamma = 0.9  # 時間割引率
epsilon = 0.5  # ε-greedy法の初期値
v = np.nanmax(Q, axis=1)  # 状態ごとに価値の最大値を求める
is_continue = True
episode = 1

V = []  # エピソードごとの状態価値を格納する
V.append(np.nanmax(Q, axis=1))  # 状態ごとに行動価値の最大値を求める

while is_continue:  # is_continueがFalseになるまで繰り返す
    print("エピソード:" + str(episode))

    # ε-greedyの値を少しずつ小さくする
    epsilon = epsilon / 2

    # Q学習で迷路を解き、移動した履歴と更新したQを求める
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)

    # 状態価値の変化
    new_v = np.nanmax(Q, axis=1)  # 状態ごとに行動価値の最大値を求める
    print(np.sum(np.abs(new_v - v)))  # 状態価値関数の変化を出力
    v = new_v
    V.append(v)  # このエピソード終了時の状態価値関数を追加

    print("迷路を解くのにかかったステップ数は" + str(len(s_a_history) - 1) + "です")

    # 100エピソード繰り返す
    episode = episode + 1
    if episode > 100:
        break
# Out:
# エピソード:1
# 0.17384394020139698
# 迷路を解くのにかかったステップ数は38です
# エピソード:2
# 0.08989667445747057
# 迷路を解くのにかかったステップ数は8です
# エピソード:3
# 0.09026297584868656
# 迷路を解くのにかかったステップ数は4です
# エピソード:4
# 0.08934187558144889
# 迷路を解くのにかかったステップ数は4です
# エピソード:5
# 0.08841451011611237
# 迷路を解くのにかかったステップ数は4です
# エピソード:6
# 0.08747442070490608
# 迷路を解くのにかかったステップ数は4です
# エピソード:7
# 0.08651276611453751
# 迷路を解くのにかかったステップ数は4です
# エピソード:8
# 0.08551978031608684
# 迷路を解くのにかかったステップ数は4です
# エピソード:9
# 0.08448581650958445
# 迷路を解くのにかかったステップ数は4です
# エピソード:10
# 0.08340206566382533
# 迷路を解くのにかかったステップ数は4です
# エピソード:11
# 0.08226102170715131
# 迷路を解くのにかかったステップ数は4です
# エピソード:12
# 0.08105675209611747
# 迷路を解くのにかかったステップ数は4です
# エピソード:13
# 0.07978502131304388
# 迷路を解くのにかかったステップ数は4です
# エピソード:14
# 0.07844330555584435
# 迷路を解くのにかかったステップ数は4です
# エピソード:15
# 0.0770307291898633
# 迷路を解くのにかかったステップ数は4です
# エピソード:16
# 0.07554794718067719
# 迷路を解くのにかかったステップ数は4です
# エピソード:17
# 0.07399699250505651
# 迷路を解くのにかかったステップ数は4です
# エピソード:18
# 0.07238110326256417
# 迷路を解くのにかかったステップ数は4です
# エピソード:19
# 0.0707045407280418
# 迷路を解くのにかかったステップ数は4です
# エピソード:20
# 0.06897240676439101
# 迷路を解くのにかかったステップ数は4です
# エピソード:21
# 0.06719046674459417
# 迷路を解くのにかかったステップ数は4です
# エピソード:22
# 0.06536498231799992
# 迷路を解くのにかかったステップ数は4です
# エピソード:23
# 0.06350255691936835
# 迷路を解くのにかかったステップ数は4です
# エピソード:24
# 0.061609995793365985
# 迷路を解くのにかかったステップ数は4です
# エピソード:25
# 0.059694181436146826
# 迷路を解くのにかかったステップ数は4です
# エピソード:26
# 0.057761964692408435
# 迷路を解くのにかかったステップ数は4です
# エピソード:27
# 0.055820071251654
# 迷路を解くのにかかったステップ数は4です
# エピソード:28
# 0.05387502292862678
# 迷路を解くのにかかったステップ数は4です
# エピソード:29
# 0.0519330728628245
# 迷路を解くのにかかったステップ数は4です
# エピソード:30
# 0.05000015360817617
# 迷路を解くのにかかったステップ数は4です
# エピソード:31
# 0.04808183698777241
# 迷路を解くのにかかったステップ数は4です
# エピソード:32
# 0.04618330454476932
# 迷路を解くのにかかったステップ数は4です
# エピソード:33
# 0.044309327416737376
# 迷路を解くのにかかったステップ数は4です
# エピソード:34
# 0.04246425448669616
# 迷路を解くのにかかったステップ数は4です
# エピソード:35
# 0.04065200771163213
# 迷路を解くのにかかったステップ数は4です
# エピソード:36
# 0.03887608359191569
# 迷路を解くのにかかったステップ数は4です
# エピソード:37
# 0.037139559817448486
# 迷路を解くのにかかったステップ数は4です
# エピソード:38
# 0.03544510620450264
# 迷路を解くのにかかったステップ数は4です
# エピソード:39
# 0.0337949991178339
# 迷路を解くのにかかったステップ数は4です
# エピソード:40
# 0.032191138653343276
# 迷路を解くのにかかったステップ数は4です
# エピソード:41
# 0.03063506793546461
# 迷路を解くのにかかったステップ数は4です
# エピソード:42
# 0.02912799395925414
# 迷路を解くのにかかったステップ数は4です
# エピソード:43
# 0.027670809478894498
# 迷路を解くのにかかったステップ数は4です
# エピソード:44
# 0.02626411551140173
# 迷路を解くのにかかったステップ数は4です
# エピソード:45
# 0.024908244086345788
# 迷路を解くのにかかったステップ数は4です
# エピソード:46
# 0.023603280929221815
# 迷路を解くのにかかったステップ数は4です
# エピソード:47
# 0.022349087817703173
# 迷路を解くのにかかったステップ数は4です
# エピソード:48
# 0.021145324396466436
# 迷路を解くのにかかったステップ数は4です
# エピソード:49
# 0.01999146927780171
# 迷路を解くのにかかったステップ数は4です
# エピソード:50
# 0.018886840292019036
# 迷路を解くのにかかったステップ数は4です
# エピソード:51
# 0.017830613784053262
# 迷路を解くのにかかったステップ数は4です
# エピソード:52
# 0.016821842880927473
# 迷路を解くのにかかったステップ数は4です
# エピソード:53
# 0.01585947467920168
# 迷路を解くのにかかったステップ数は4です
# エピソード:54
# 0.014942366322524547
# 迷路を解くのにかかったステップ数は4です
# エピソード:55
# 0.014069299957234827
# 迷路を解くのにかかったステップ数は4です
# エピソード:56
# 0.01323899656895211
# 迷路を解くのにかかったステップ数は4です
# エピソード:57
# 0.012450128715523645
# 迷路を解くのにかかったステップ数は4です
# エピソード:58
# 0.011701332181865864
# 迷路を解くのにかかったステップ数は4です
# エピソード:59
# 0.010991216590395148
# 迷路を解くのにかかったステップ数は4です
# エピソード:60
# 0.010318375007132063
# 迷路を解くのにかかったステップ数は4です
# エピソード:61
# 0.009681392588420379
# 迷路を解くのにかかったステップ数は4です
# エピソード:62
# 0.009078854316721618
# 迷路を解くのにかかったステップ数は4です
# エピソード:63
# 0.008509351876314297
# 迷路を解くのにかかったステップ数は4です
# エピソード:64
# 0.00797148972111783
# 迷路を解くのにかかったステップ数は4です
# エピソード:65
# 0.0074638903874350015
# 迷路を解くのにかかったステップ数は4です
# エピソード:66
# 0.006985199104264872
# 迷路を解くのにかかったステップ数は4です
# エピソード:67
# 0.006534087753148787
# 迷路を解くのにかかったステップ数は4です
# エピソード:68
# 0.006109258228343739
# 迷路を解くのにかかったステップ数は4です
# エピソード:69
# 0.005709445246574463
# 迷路を解くのにかかったステップ数は4です
# エピソード:70
# 0.005333418653791333
# 迷路を解くのにかかったステップ数は4です
# エピソード:71
# 0.004979985274306098
# 迷路を解くのにかかったステップ数は4です
# エピソード:72
# 0.00464799034547092
# 迷路を解くのにかかったステップ数は4です
# エピソード:73
# 0.004336318578745946
# 迷路を解くのにかかったステップ数は4です
# エピソード:74
# 0.004043894885620625
# 迷路を解くのにかかったステップ数は4です
# エピソード:75
# 0.0037696848044499465
# 迷路を解くのにかかったステップ数は4です
# エピソード:76
# 0.0035126946618632138
# 迷路を解くのにかかったステップ数は4です
# エピソード:77
# 0.003271971500035553
# 迷路を解くのにかかったステップ数は4です
# エピソード:78
# 0.0030466027987928745
# 迷路を解くのにかかったステップ数は4です
# エピソード:79
# 0.002835716019275125
# 迷路を解くのにかかったステップ数は4です
# エピソード:80
# 0.002638477993712751
# 迷路を解くのにかかったステップ数は4です
# エピソード:81
# 0.0024540941837948305
# 迷路を解くのにかかったステップ数は4です
# エピソード:82
# 0.0022818078281359178
# 迷路を解くのにかかったステップ数は4です
# エピソード:83
# 0.0021208989974665915
# 迷路を解くのにかかったステップ数は4です
# エピソード:84
# 0.0019706835744097706
# 迷路を解くのにかかったステップ数は4です
# エピソード:85
# 0.0018305121730441964
# 迷路を解くのにかかったステップ数は4です
# エピソード:86
# 0.0016997690119002762
# 迷路を解くのにかかったステップ数は4です
# エピソード:87
# 0.001577870752586752
# 迷路を解くのにかかったステップ数は4です
# エピソード:88
# 0.0014642653149044005
# 迷路を解くのにかかったステップ数は4です
# エピソード:89
# 0.0013584306780506372
# 迷路を解くのにかかったステップ数は4です
# エピソード:90
# 0.0012598736763820284
# 迷路を解くのにかかったステップ数は4です
# エピソード:91
# 0.0011681287971385679
# 迷路を解くのにかかったステップ数は4です
# エピソード:92
# 0.0010827569865689002
# 迷路を解くのにかかったステップ数は4です
# エピソード:93
# 0.0010033444700155991
# 迷路を解くのにかかったステップ数は4です
# エピソード:94
# 0.0009295015907130333
# 迷路を解くのにかかったステップ数は4です
# エピソード:95
# 0.0008608616713235984
# 迷路を解くのにかかったステップ数は4です
# エピソード:96
# 0.0007970799015772911
# 迷路を解くのにかかったステップ数は4です
# エピソード:97
# 0.0007378322547870741
# 迷路を解くのにかかったステップ数は4です
# エピソード:98
# 0.0006828144354811272
# 迷路を解くのにかかったステップ数は4です
# エピソード:99
# 0.00063174085991069
# 迷路を解くのにかかったステップ数は4です
# エピソード:100
# 0.0005843436707743122
# 迷路を解くのにかかったステップ数は4です

# %% [markdown]
# # 状態価値の変化を可視化します

# %%
# 参考URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML
import matplotlib.cm as cm  # color map


def init():
    # 背景画像の初期化
    line.set_data([], [])
    return (line,)


def animate(i):
    # フレームごとの描画内容
    # 各マスに状態価値の大きさに基づく色付きの四角を描画
    line, = ax.plot([0.5], [2.5], marker="s",
                    color=cm.jet(V[i][0]), markersize=85)  # S0
    line, = ax.plot([1.5], [2.5], marker="s",
                    color=cm.jet(V[i][1]), markersize=85)  # S1
    line, = ax.plot([2.5], [2.5], marker="s",
                    color=cm.jet(V[i][2]), markersize=85)  # S2
    line, = ax.plot([0.5], [1.5], marker="s",
                    color=cm.jet(V[i][3]), markersize=85)  # S3
    line, = ax.plot([1.5], [1.5], marker="s",
                    color=cm.jet(V[i][4]), markersize=85)  # S4
    line, = ax.plot([2.5], [1.5], marker="s",
                    color=cm.jet(V[i][5]), markersize=85)  # S5
    line, = ax.plot([0.5], [0.5], marker="s",
                    color=cm.jet(V[i][6]), markersize=85)  # S6
    line, = ax.plot([1.5], [0.5], marker="s",
                    color=cm.jet(V[i][7]), markersize=85)  # S7
    line, = ax.plot([2.5], [0.5], marker="s",
                    color=cm.jet(1.0), markersize=85)  # S8
    return (line,)


#　初期化関数とフレームごとの描画関数を用いて動画を作成
anim = animation.FuncAnimation(
    fig, animate, init_func=init, frames=len(V), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imge4f18c78d85e4bdda040cfff61a3e275">
#     <br>
#     <input id="_anim_slidere4f18c78d85e4bdda040cfff61a3e275" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anime4f18c78d85e4bdda040cfff61a3e275.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anime4f18c78d85e4bdda040cfff61a3e275.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anime4f18c78d85e4bdda040cfff61a3e275.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anime4f18c78d85e4bdda040cfff61a3e275.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anime4f18c78d85e4bdda040cfff61a3e275.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anime4f18c78d85e4bdda040cfff61a3e275.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anime4f18c78d85e4bdda040cfff61a3e275.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anime4f18c78d85e4bdda040cfff61a3e275.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anime4f18c78d85e4bdda040cfff61a3e275.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anime4f18c78d85e4bdda040cfff61a3e275.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selecte4f18c78d85e4bdda040cfff61a3e275" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge4f18c78d85e4bdda040cfff61a3e275";
#     var slider_id = "_anim_slidere4f18c78d85e4bdda040cfff61a3e275";
#     var loop_select_id = "_anim_loop_selecte4f18c78d85e4bdda040cfff61a3e275";
#     var frames = new Array(101);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvqOYd8AAAFURJREFUeJzt3XmUJWV5x/FvMz07AwMM3GYbml0F\
# GYFRhkVF2TKKh8gWzHE9QYUIqBFNjEaNxoWoUdDEoMQIYhAXFBlFEESCGtnEBVkOBIZFuY3DAMMs\
# MiCdP55q+05P3+nuye2qp6u/n3PuabqqLufh7eJ333qqblVXf39/P5KkdDapugBJ0vAMaElKyoCW\
# pKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQM\
# aElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElK\
# yoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCW\
# pKQMaElKqrvqAjbGvHnz6O3trboMSTWzdOlSli1bVnUZfzIhA7q3t5ebbrqp6jIk1czChQurLmEd\
# tjgkKSkDWpKSmpAtjuH09NxDX98fqy6jVhqNKTSbu7Rd39PzWfr6VpdYUf01GrNoNk9ru76n5376\
# +p4psaL6azQ2odmcX3UZw6rNDNpw7ryRxtRw7ryRxtRw7rzMY1qbgJakujGgJSkpA1qSkjKgJSkp\
# A1qSkjKgJSkpA1qSkjKgJSkpA1qSkjKgJSkpA1qSkjKgJSkpA1qSkjKgJSkpA1qSkjKgJSkpA1qS\
# kjKgJSkpA1qSkjKgJSkpA1qSkjKgJSkpA1qSkjKgJSkpA1qSkjKgJSkpA1qSkjKgJSkpA1qSkuqu\
# uoB6Wg6cA1wLPAxsBuwOvBk4GOgHPgN8DXgcWAC8v9hGY7cS+AFwJ7ACmAk0gEOBPYBbgZ8BvwNW\
# AW8Cdq2i0Jp5BPg0cA3we2AOsCdwCrAI+CTwI+B+YFPgQOBdwPYV1DoxGdDj4jTgD8CHgZ2IHflG\
# 4NFi/ReA/wQ+BuwM/CvwBuD7xI6ssbkQWAscD2xFBPY9wOpi/Vri77AfcHEVBdbUqcR+fhaD+/n1\
# wGPAGuKD8TTg2cATxP8Prwcux+gZHUep41YANxEBfFCxbHtgn+Kf+4HziVncUcWys4jZxRLgpNIq\
# rYc1wL3AycBuxbItgB1bttmv+LmqxLrqbgUx6fgycVQIsANxNDjgwiHv+QhwJHA38KzxLrAW7EF3\
# 3CxgNvBD4Mlh1j9AHA4e3LJsBrAQ+Pm4V1c/04rXbcBTFdcymQzs51cx/H4+nJXFz83HpaI6cgbd\
# cd1E6+K9xOH0c4gZ3GJidrGs2G7ekPfNA/pKqrFOpgAnAt8EbgC2Iw639wHmV1hX3XUDHwfeDVwE\
# 7AXsD7wM2HeY7dcSLY7DgG1LqnHiM6DHxVHECaqbgFuA64AvAm8HDii26Rrynv5hlml0nkscMt9L\
# nJC6kxjzo4CXVlhX3S0mxvcGYj+/FjgPOBN4S8t2TxP7/gri/ItGyxbHuJlOtDFOI2bSxwOfJfqj\
# EG2OVo8QJ7i0caYSV2wcToTD84nD76erLGoSmA68EDiDOIo5ETibmDFDjP8ZwB3AVxjc/zUaBnRp\
# diN21nnA1sBPWtY9Scy29xvmfdo42wDPYECXbXdizJ8kzgmcToTzRcR+r7GwxdFxjwJvBY4jrgmd\
# TVxudB5xpcYc4HXA54BdiMvs/q3Y7ugK6p3oVhEzs4VEb3M68CBxuL0rcQJ2NYOXfkEcrcwk/hZz\
# Sq63Lh4ljlROINpLmwK/As4lrl6aCfx1sew8on03cNQ4h/i7aCQGdMfNJk4Gnk/0Q9cSX5o4mthh\
# Ad5IXD/6QQa/qPJFvAZ6Y0wnTgb+hAjep4kvBj2POCEFcYXH11ve883i5+HAEeW

# %%
# %%bash
# git commit -a -m "again, leavng Q-learning"
# Out:
# [master 50933fb] again, leavng Q-learning
#  2 files changed, 1686 insertions(+), 11371 deletions(-)
#  rewrite program/2_6_Qlearning.ipynb (96%)
