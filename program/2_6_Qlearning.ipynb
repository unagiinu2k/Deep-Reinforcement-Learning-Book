# %% [markdown]
# ** 2.6 Q学習で迷路を攻略 **

# %% [markdown]
# # 使用するパッケージの宣言

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 初期位置での迷路の様子

# %%
# 図を描く大きさと、図の変数名を宣言
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 赤い壁を描く
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 状態を示す文字S0～S8を描く
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 描画範囲の設定と目盛りを消す設定
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom='off', top='off',
                labelbottom='off', right='off', left='off', labelleft='off')

# 現在地S0に緑丸を描画する
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)

# %% [markdown]
# # 初期の方策を決定するパラメータtheta_0を設定

# %%
# 行は状態0～7、列は移動方向で↑、→、↓、←を表す
theta_0 = np.array([[np.nan, 1, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1],  # s1
                    [np.nan, np.nan, 1, 1],  # s2
                    [1, 1, 1, np.nan],  # s3
                    [np.nan, np.nan, 1, 1],  # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],  # s7、※s8はゴールなので、方策はなし
                    ])

# %% [markdown]
# # 方策パラメータtheta_0をランダム方策piに変換する関数の定義

# %%
def simple_convert_into_pi_from_theta(theta):
    '''単純に割合を計算する'''

    [m, n] = theta.shape  # thetaの行列サイズを取得
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])  # 割合の計算

    pi = np.nan_to_num(pi)  # nanを0に変換

    return pi

# ランダム行動方策pi_0を求める
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %% [markdown]
# # 初期の行動価値関数Qを設定

# %%
[a, b] = theta_0.shape  # 行と列の数をa, bに格納
Q = np.random.rand(a, b) * theta_0 * 0.1
# *theta0をすることで要素ごとに掛け算をし、Qの壁方向の値がnanになる

# %% [markdown]
# # ε-greedy法を実装

# %%
def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]

    # 行動を決める
    if np.random.rand() < epsilon:
        # εの確率でランダムに動く
        next_direction = np.random.choice(direction, p=pi_0[s, :])
    else:
        # Qの最大値の行動を採用する
        next_direction = direction[np.nanargmax(Q[s, :])]

    # 行動をindexに
    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3

    return action

# %% [markdown]
# ## 番号で表されたactionをノードに変換。引数5個あるが最初のふたつ（s,a)しか使っていない

# %%
def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a]  # 行動aの方向

    # 行動から次の状態を決める
    if next_direction == "up":
        s_next = s - 3  # 上に移動するときは状態の数字が3小さくなる
    elif next_direction == "right":
        s_next = s + 1  # 右に移動するときは状態の数字が1大きくなる
    elif next_direction == "down":
        s_next = s + 3  # 下に移動するときは状態の数字が3大きくなる
    elif next_direction == "left":
        s_next = s - 1  # 左に移動するときは状態の数字が1小さくなる

    return s_next

# %% [markdown]
# ## subsandbox

# %%
Q = np.random.rand(a, b) * theta_0 * 0.1

action = get_action(3, Q , epsilon , pi_0)
print(action)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-60647ef067cd> in <module>
#       1 Q = np.random.rand(a, b) * theta_0 * 0.1
#       2
# ----> 3 action = get_action(3, Q , epsilon , pi_0)
#       4 print(action)
#
# NameError: name 'epsilon' is not defined

# %%
epsilon
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-026a7c51f0ed> in <module>
# ----> 1 epsilon
#
# NameError: name 'epsilon' is not defined

# %%
get_s_next(0 , action , "meaningless" , "inputs" , "here")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3960cd884c02> in <module>
# ----> 1 get_s_next(0 , action , "meaningless" , "inputs" , "here")
#
# NameError: name 'action' is not defined

# %%
Q
# Out:
# array([[       nan, 0.02378444, 0.00856995,        nan],
#        [       nan, 0.03525471,        nan, 0.02652187],
#        [       nan,        nan, 0.02677074, 0.03500999],
#        [0.00263825, 0.03986688, 0.01556495,        nan],
#        [       nan,        nan, 0.00031737, 0.00124878],
#        [0.06418558,        nan,        nan,        nan],
#        [0.03631691,        nan,        nan,        nan],
#        [0.07522645, 0.0425791 ,        nan,        nan]])

# %% [markdown]
# # Q学習による行動価値関数Qの更新

# %% [markdown]
# - a_nextを引数として持たないのがポイント
# - ただし、s_nextは使っている

# %% [markdown]
# **（pythonの関数は基本参照渡しであることに注意） **
#
# ただし、変更されてしまうかどうかは型依存らしい・・・
# http://amacbee.hatenablog.com/entry/2016/12/07/004510

# %%
def Q_learning(s, a, r, s_next, Q, eta, gamma):

    if s_next == 8:  # ゴールした場合
        Q[s, a] = Q[s, a] + eta * (r - Q[s, a])

    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * np.nanmax(Q[s_next,: ]) - Q[s, a])

    return Q

# %% [markdown]
# ## subsandbox

# %%
def reward(s_next):
    if s_next == 8:
        return 1
    else:
        return 0

# %%
s = 0

# %%
Q = np.random.rand(a, b) * theta_0 * 0.1

# %%
epsilon = 0.5

# %%
action = get_action(s, Q , epsilon , pi_0)
print("next action is {} ".format(action))

s_next = get_s_next(0 , action , "meaningless" , "inputs" , "here")
print("next state is {}".format(s_next))
# Out:
# next action is 1
# next state is 1

# %%
gamma
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-37f385b028bf> in <module>
# ----> 1 gamma
#
# NameError: name 'gamma' is not defined

# %% [markdown]
# ### （参照渡しなため）Q_learningをQで受けなくても引数がQなだけでQは更新されてしまうことに注意

# %%
Qold = Q.copy()

# %%
Q_learning(s, action, reward(s_next), s_next, Q, eta, gamma)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-1d9a8839fb93> in <module>
# ----> 1 Q_learning(s, action, reward(s_next), s_next, Q, eta, gamma)
#
# NameError: name 'eta' is not defined

# %%
Q - Qold
# Out:
# array([[nan,  0.,  0., nan],
#        [nan,  0., nan,  0.],
#        [nan, nan,  0.,  0.],
#        [ 0.,  0.,  0., nan],
#        [nan, nan,  0.,  0.],
#        [ 0., nan, nan, nan],
#        [ 0., nan, nan, nan],
#        [ 0.,  0., nan, nan]])

# %% [markdown]
# # Q学習で迷路を解く関数の定義、状態と行動の履歴および更新したQを出力

# %%
def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi):
    s = 0  # スタート地点
    a = a_next = get_action(s, Q, epsilon, pi)  # 初期の行動
    s_a_history = [[0, np.nan]]  # エージェントの移動を記録するリスト

    while (1):  # ゴールするまでループ
        a = a_next  # 行動更新

        s_a_history[-1][1] = a
        # 現在の状態（つまり一番最後なのでindex=-1）に行動を代入

        s_next = get_s_next(s, a, Q, epsilon, pi)
        # 次の状態を格納

        s_a_history.append([s_next, np.nan])
        # 次の状態を代入。行動はまだ分からないのでnanにしておく

        # 報酬を与え,　次の行動を求めます
        if s_next == 8:
            r = 1  # ゴールにたどり着いたなら報酬を与える
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            # 次の行動a_nextを求めます。

        # 価値関数を更新
        Q = Q_learning(s, a, r, s_next, Q, eta, gamma)

        # 終了判定
        if s_next == 8:  # ゴール地点なら終了
            break
        else:
            s = s_next

    return [s_a_history, Q]

# %% [markdown]
# # Q学習で迷路を解く

# %%
eta = 0.1  # 学習率
gamma = 0.9  # 時間割引率
epsilon = 0.5  # ε-greedy法の初期値
v = np.nanmax(Q, axis=1)  # 状態ごとに価値の最大値を求める
is_continue = True
episode = 1

V = []  # エピソードごとの状態価値を格納する
V.append(np.nanmax(Q, axis=1))  # 状態ごとに行動価値の最大値を求める

while is_continue:  # is_continueがFalseになるまで繰り返す
    print("エピソード:" + str(episode))

    # ε-greedyの値を少しずつ小さくする
    epsilon = epsilon / 2

    # Q学習で迷路を解き、移動した履歴と更新したQを求める
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)

    # 状態価値の変化
    new_v = np.nanmax(Q, axis=1)  # 状態ごとに行動価値の最大値を求める
    print(np.sum(np.abs(new_v - v)))  # 状態価値関数の変化を出力
    v = new_v
    V.append(v)  # このエピソード終了時の状態価値関数を追加

    print("迷路を解くのにかかったステップ数は" + str(len(s_a_history) - 1) + "です")

    # 100エピソード繰り返す
    episode = episode + 1
    if episode > 100:
        break
# Out:
# エピソード:1
# 0.3190909141842563
# 迷路を解くのにかかったステップ数は536です
# エピソード:2
# 0.12670730994811363
# 迷路を解くのにかかったステップ数は176です
# エピソード:3
# 0.09601700686208628
# 迷路を解くのにかかったステップ数は16です
# エピソード:4
# 0.09326615875605221
# 迷路を解くのにかかったステップ数は6です
# エピソード:5
# 0.09252560864269899
# 迷路を解くのにかかったステップ数は8です
# エピソード:6
# 0.09089000581815143
# 迷路を解くのにかかったステップ数は4です
# エピソード:7
# 0.08995145501337093
# 迷路を解くのにかかったステップ数は4です
# エピソード:8
# 0.08897646230311379
# 迷路を解くのにかかったステップ数は4です
# エピソード:9
# 0.08795281171951469
# 迷路を解くのにかかったステップ数は4です
# エピソード:10
# 0.08687002539882023
# 迷路を解くのにかかったステップ数は4です
# エピソード:11
# 0.08571964092051852
# 迷路を解くのにかかったステップ数は4です
# エピソード:12
# 0.08449532593263238
# 迷路を解くのにかかったステップ数は4です
# エピソード:13
# 0.08319287277754256
# 迷路を解くのにかかったステップ数は4です
# エピソード:14
# 0.08181010722662622
# 迷路を解くのにかかったステップ数は4です
# エピソード:15
# 0.08034673832860105
# 迷路を解くのにかかったステップ数は4です
# エピソード:16
# 0.07880417053647443
# 迷路を解くのにかかったステップ数は4です
# エピソード:17
# 0.07718529449780347
# 迷路を解くのにかかったステップ数は4です
# エピソード:18
# 0.07549426899963743
# 迷路を解くのにかかったステップ数は4です
# エピソード:19
# 0.07373630340633483
# 迷路を解くのにかかったステップ数は4です
# エピソード:20
# 0.07191744739118118
# 迷路を解くのにかかったステップ数は4です
# エピソード:21
# 0.07004439273639859
# 迷路を解くのにかかったステップ数は4です
# エピソード:22
# 0.06812429037210538
# 迷路を解くのにかかったステップ数は4です
# エピソード:23
# 0.06616458456846941
# 迷路を解くのにかかったステップ数は4です
# エピソード:24
# 0.06417286522404247
# 迷路を解くのにかかったステップ数は4です
# エピソード:25
# 0.062156738454500066
# 迷路を解くのにかかったステップ数は4です
# エピソード:26
# 0.060123715135871586
# 迷路を解くのにかかったステップ数は4です
# エピソード:27
# 0.058081116658202925
# 迷路を解くのにかかったステップ数は4です
# エピソード:28
# 0.05603599686902244
# 迷路を解くのにかかったステップ数は4です
# エピソード:29
# 0.05399507900581868
# 迷路を解くのにかかったステップ数は4です
# エピソード:30
# 0.051964706312172204
# 迷路を解くのにかかったステップ数は4です
# エピソード:31
# 0.04995080498616422
# 迷路を解くのにかかったステップ数は4です
# エピソード:32
# 0.047958858108235636
# 迷路を解くのにかかったステップ数は4です
# エピソード:33
# 0.04599388922746661
# 迷路を解くのにかかったステップ数は4です
# エピソード:34
# 0.04406045434109335
# 迷路を解くのにかかったステップ数は4です
# エピソード:35
# 0.04216264107464135
# 迷路を解くのにかかったステップ数は4です
# エピソード:36
# 0.04030407395347385
# 迷路を解くのにかかったステップ数は4です
# エピソード:37
# 0.03848792474623691
# 迷路を解くのにかかったステップ数は4です
# エピソード:38
# 0.03671692695303236
# 迷路を解くのにかかったステップ数は4です
# エピソード:39
# 0.034993393603462875
# 迷路を解くのにかかったステップ数は4です
# エピソード:40
# 0.03331923761988148
# 迷路を解くのにかかったステップ数は4です
# エピソード:41
# 0.0316959940877804
# 迷路を解くのにかかったステップ数は4です
# エピソード:42
# 0.030124843857198658
# 迷路を解くのにかかったステップ数は4です
# エピソード:43
# 0.028606637975644333
# 迷路を解くのにかかったステップ数は4です
# エピソード:44
# 0.027141922523898132
# 迷路を解くのにかかったステップ数は4です
# エピソード:45
# 0.025730963491000014
# 迷路を解くのにかかったステップ数は4です
# エピソード:46
# 0.024373771383726206
# 迷路を解くのにかかったステップ数は4です
# エピソード:47
# 0.023070125319020862
# 迷路を解くのにかかったステップ数は4です
# エピソード:48
# 0.021819596395391883
# 迷路を解くのにかかったステップ数は4です
# エピソード:49
# 0.020621570181470594
# 迷路を解くのにかかったステップ数は4です
# エピソード:50
# 0.01947526819709111
# 迷路を解くのにかかったステップ数は4です
# エピソード:51
# 0.0183797682947342
# 迷路を解くのにかかったステップ数は4です
# エピソード:52
# 0.01733402387733196
# 迷路を解くのにかかったステップ数は4です
# エピソード:53
# 0.016336881912641932
# 迷路を解くのにかかったステップ数は4です
# エピソード:54
# 0.015387099725010511
# 迷路を解くのにかかったステップ数は4です
# エピソード:55
# 0.014483360562723702
# 迷路を解くのにかかったステップ数は4です
# エピソード:56
# 0.013624287953599712
# 迷路を解くのにかかったステップ数は4です
# エピソード:57
# 0.012808458873368678
# 迷路を解くのにかかったステップ数は4です
# エピソード:58
# 0.012034415760955541
# 迷路を解くのにかかったステップ数は4です
# エピソード:59
# 0.011300677422361738
# 迷路を解くのにかかったステップ数は4です
# エピソード:60
# 0.010605748870644582
# 迷路を解くのにかかったステップ数は4です
# エピソード:61
# 0.009948130153771717
# 迷路を解くのにかかったステップ数は4です
# エピソード:62
# 0.0093263242250895
# 迷路を解くのにかかったステップ数は4です
# エピソード:63
# 0.008738843912979188
# 迷路を解くのにかかったステップ数は4です
# エピソード:64
# 0.008184218047159408
# 迷路を解くのにかかったステップ数は4です
# エピソード:65
# 0.007660996799165876
# 迷路を解くのにかかったステップ数は4です
# エピソード:66
# 0.007167756293968264
# 迷路を解くのにかかったステップ数は4です
# エピソード:67
# 0.006703102548551332
# 迷路を解くのにかかったステップ数は4です
# エピソード:68
# 0.006265674791724907
# 迷路を解くのにかかったステップ数は4です
# エピソード:69
# 0.005854148217529498
# 迷路を解くのにかかったステップ数は4です
# エピソード:70
# 0.005467236222425509
# 迷路を解くのにかかったステップ数は4です
# エピソード:71
# 0.005103692174104779
# 迷路を解くのにかかったステップ数は4です
# エピソード:72
# 0.0047623107572535295
# 迷路を解くのにかかったステップ数は4です
# エピソード:73
# 0.004441928939035722
# 迷路を解くのにかかったステップ数は4です
# エピソード:74
# 0.004141426594432507
# 迷路を解くのにかかったステップ数は4です
# エピソード:75
# 0.003859726828964405
# 迷路を解くのにかかったステップ数は4です
# エピソード:76
# 0.0035957960337243966
# 迷路を解くのにかかったステップ数は4です
# エピソード:77
# 0.0033486437051041262
# 迷路を解くのにかかったステップ数は4です
# エピソード:78
# 0.003117322059127625
# 迷路を解くのにかかったステップ数は4です
# エピソード:79
# 0.0029009254679103202
# 迷路を解くのにかかったステップ数は4です
# エピソード:80
# 0.0026985897434737005
# 迷路を解くのにかかったステップ数は4です
# エピソード:81
# 0.0025094912919585433
# 迷路を解くのにかかったステップ数は4です
# エピソード:82
# 0.002332846159201596
# 迷路を解くのにかかったステップ数は4です
# エピソード:83
# 0.0021679089866804002
# 迷路を解くのにかかったステップ数は4です
# エピソード:84
# 0.002013971894987643
# 迷路を解くのにかかったステップ数は4です
# エピソード:85
# 0.0018703633102670203
# 迷路を解くのにかかったステップ数は4です
# エピソード:86
# 0.0017364467474287881
# 迷路を解くのにかかったステップ数は4です
# エピソード:87
# 0.0016116195624689134
# 迷路を解くのにかかったステップ数は4です
# エピソード:88
# 0.001495311684821754
# 迷路を解くのにかかったステップ数は4です
# エピソード:89
# 0.001386984339394881
# 迷路を解くのにかかったステップ数は4です
# エピソード:90
# 0.0012861287667601529
# 迷路を解くのにかかったステップ数は4です
# エピソード:91
# 0.0011922649488809167
# 迷路を解くのにかかったステップ数は4です
# エピソード:92
# 0.0011049403467814356
# 迷路を解くのにかかったステップ数は4です
# エピソード:93
# 0.0010237286556471492
# 迷路を解くのにかかったステップ数は4です
# エピソード:94
# 0.0009482285820375802
# 迷路を解くのにかかったステップ数は4です
# エピソード:95
# 0.0008780626471440733
# 迷路を解くのにかかったステップ数は4です
# エピソード:96
# 0.000812876019359754
# 迷路を解くのにかかったステップ数は4です
# エピソード:97
# 0.000752335378826352
# 迷路を解くのにかかったステップ数は4です
# エピソード:98
# 0.000696127816083858
# 迷路を解くのにかかったステップ数は4です
# エピソード:99
# 0.0006439597664674723
# 迷路を解くのにかかったステップ数は4です
# エピソード:100
# 0.0005955559814710965
# 迷路を解くのにかかったステップ数は4です

# %% [markdown]
# # 状態価値の変化を可視化します

# %%
# 参考URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML
import matplotlib.cm as cm  # color map


def init():
    # 背景画像の初期化
    line.set_data([], [])
    return (line,)


def animate(i):
    # フレームごとの描画内容
    # 各マスに状態価値の大きさに基づく色付きの四角を描画
    line, = ax.plot([0.5], [2.5], marker="s",
                    color=cm.jet(V[i][0]), markersize=85)  # S0
    line, = ax.plot([1.5], [2.5], marker="s",
                    color=cm.jet(V[i][1]), markersize=85)  # S1
    line, = ax.plot([2.5], [2.5], marker="s",
                    color=cm.jet(V[i][2]), markersize=85)  # S2
    line, = ax.plot([0.5], [1.5], marker="s",
                    color=cm.jet(V[i][3]), markersize=85)  # S3
    line, = ax.plot([1.5], [1.5], marker="s",
                    color=cm.jet(V[i][4]), markersize=85)  # S4
    line, = ax.plot([2.5], [1.5], marker="s",
                    color=cm.jet(V[i][5]), markersize=85)  # S5
    line, = ax.plot([0.5], [0.5], marker="s",
                    color=cm.jet(V[i][6]), markersize=85)  # S6
    line, = ax.plot([1.5], [0.5], marker="s",
                    color=cm.jet(V[i][7]), markersize=85)  # S7
    line, = ax.plot([2.5], [0.5], marker="s",
                    color=cm.jet(1.0), markersize=85)  # S8
    return (line,)


#　初期化関数とフレームごとの描画関数を用いて動画を作成
anim = animation.FuncAnimation(
    fig, animate, init_func=init, frames=len(V), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgd99cdd54dce64b3ab5651a4da1ac4807">
#   <div class="anim-controls">
#     <input id="_anim_sliderd99cdd54dce64b3ab5651a4da1ac4807" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animd99cdd54dce64b3ab5651a4da1ac4807.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animd99cdd54dce64b3ab5651a4da1ac4807.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animd99cdd54dce64b3ab5651a4da1ac4807.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animd99cdd54dce64b3ab5651a4da1ac4807.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animd99cdd54dce64b3ab5651a4da1ac4807.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animd99cdd54dce64b3ab5651a4da1ac4807.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animd99cdd54dce64b3ab5651a4da1ac4807.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animd99cdd54dce64b3ab5651a4da1ac4807.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animd99cdd54dce64b3ab5651a4da1ac4807.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animd99cdd54dce64b3ab5651a4da1ac4807.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectd99cdd54dce64b3ab5651a4da1ac4807" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_d99cdd54dce64b3ab5651a4da1ac4807"
#              checked>
#       <label for="_anim_radio1_d99cdd54dce64b3ab5651a4da1ac4807">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_d99cdd54dce64b3ab5651a4da1ac4807"
#              >
#       <label for="_anim_radio2_d99cdd54dce64b3ab5651a4da1ac4807">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_d99cdd54dce64b3ab5651a4da1ac4807"
#              >
#       <label for="_anim_radio3_d99cdd54dce64b3ab5651a4da1ac4807">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgd99cdd54dce64b3ab5651a4da1ac4807";
#     var slider_id = "_anim_sliderd99cdd54dce64b3ab5651a4da1ac4807";
#     var loop_select_id = "_anim_loop_selectd99cdd54dce64b3ab5651a4da1ac4807";
#     var frames = new Array(101);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjAsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+17YcXAAAgAElEQVR4nO3de3xU9Z3/8dfALMg1EAxJcKgagxoC\
# SQoDwRYRbKmaaqqAAuUnuLCOKIjFumt/2xZ/UGvZXV3FwtJmoSB2C91Cfw0q4NYLtrLcws0i9rfR\
# EgiRoQENF+USwvn98Z2EXCYkwZyZ70zez8djHsmc852ZD98M7/me7zlzjsdxHAcREbFOu2gXICIi\
# 4SmgRUQspYAWEbGUAlpExFIKaBERSymgRUQspYAWEbGUAlpExFIKaBERSymgRUQspYAWEbGUAlpE\
# xFIKaBERSymgRUQspYAWEbGUAlpExFIKaBERSymgRUQspYAWEbGUAlpExFIKaBERSymgRUQspYAW\
# EbGUAlpExFIKaBERSymgRUQspYAWEbGUAlpExFIKaBERSymgRUQspYAWEbGUAlpExFIKaBERSymg\
# RUQspYAWEbGUAlpExFIKaBERS

# %%
# %%bash
# git commit -a -m "again, leavng Q-learning"
# Out:
# [master 50933fb] again, leavng Q-learning
#  2 files changed, 1686 insertions(+), 11371 deletions(-)
#  rewrite program/2_6_Qlearning.ipynb (96%)

# %% [markdown]
# # sandbox

# %%
epsilon
# Out:
# 3.944304526105059e-31

# %%
import sys

# %%
sys.version
# Out:
# '3.5.4 |Anaconda custom (64-bit)| (default, Nov 20 2017, 18:44:38) \n[GCC 7.2.0]'
