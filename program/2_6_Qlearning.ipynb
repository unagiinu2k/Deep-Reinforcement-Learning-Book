# %% [markdown]
# ** 2.6 Q学習で迷路を攻略 **

# %% [markdown]
# # 使用するパッケージの宣言

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 初期位置での迷路の様子

# %%
# 図を描く大きさと、図の変数名を宣言
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 赤い壁を描く
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 状態を示す文字S0～S8を描く
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 描画範囲の設定と目盛りを消す設定
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom='off', top='off',
                labelbottom='off', right='off', left='off', labelleft='off')

# 現在地S0に緑丸を描画する
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)
# Out:
# /home/toshinao/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %% [markdown]
# # 初期の方策を決定するパラメータtheta_0を設定

# %%
# 行は状態0～7、列は移動方向で↑、→、↓、←を表す
theta_0 = np.array([[np.nan, 1, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1],  # s1
                    [np.nan, np.nan, 1, 1],  # s2
                    [1, 1, 1, np.nan],  # s3
                    [np.nan, np.nan, 1, 1],  # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],  # s7、※s8はゴールなので、方策はなし
                    ])

# %% [markdown]
# # 方策パラメータtheta_0をランダム方策piに変換する関数の定義

# %%
def simple_convert_into_pi_from_theta(theta):
    '''単純に割合を計算する'''

    [m, n] = theta.shape  # thetaの行列サイズを取得
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])  # 割合の計算

    pi = np.nan_to_num(pi)  # nanを0に変換

    return pi

# ランダム行動方策pi_0を求める
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %% [markdown]
# # 初期の行動価値関数Qを設定

# %%
[a, b] = theta_0.shape  # 行と列の数をa, bに格納
Q = np.random.rand(a, b) * theta_0 * 0.1
# *theta0をすることで要素ごとに掛け算をし、Qの壁方向の値がnanになる

# %% [markdown]
# # ε-greedy法を実装

# %%
def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]

    # 行動を決める
    if np.random.rand() < epsilon:
        # εの確率でランダムに動く
        next_direction = np.random.choice(direction, p=pi_0[s, :])
    else:
        # Qの最大値の行動を採用する
        next_direction = direction[np.nanargmax(Q[s, :])]

    # 行動をindexに
    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3

    return action

# %% [markdown]
# ## 番号で表されたactionをノードに変換。引数5個あるが最初のふたつ（s,a)しか使っていない

# %%
def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a]  # 行動aの方向

    # 行動から次の状態を決める
    if next_direction == "up":
        s_next = s - 3  # 上に移動するときは状態の数字が3小さくなる
    elif next_direction == "right":
        s_next = s + 1  # 右に移動するときは状態の数字が1大きくなる
    elif next_direction == "down":
        s_next = s + 3  # 下に移動するときは状態の数字が3大きくなる
    elif next_direction == "left":
        s_next = s - 1  # 左に移動するときは状態の数字が1小さくなる

    return s_next

# %% [markdown]
# ## subsandbox

# %%
Q = np.random.rand(a, b) * theta_0 * 0.1

action = get_action(3, Q , epsilon , pi_0)
print(action)
# Out:
# 2

# %%
epsilon
# Out:
# 3.944304526105059e-31

# %%
get_s_next(0 , action , "meaningless" , "inputs" , "here")
# Out:
# -3

# %%
Q
# Out:
# array([[       nan, 0.00870867, 0.06907827,        nan],
#        [       nan, 0.02045549,        nan, 0.08692077],
#        [       nan,        nan, 0.04094124, 0.03716102],
#        [0.04298617, 0.08022878, 0.05195599,        nan],
#        [       nan,        nan, 0.0457183 , 0.0670113 ],
#        [0.05960136,        nan,        nan,        nan],
#        [0.06632814,        nan,        nan,        nan],
#        [0.01734132, 0.02122782,        nan,        nan]])

# %% [markdown]
# # Q学習による行動価値関数Qの更新

# %% [markdown]
# - a_nextを引数として持たないのがポイント
# - ただし、s_nextは使っている

# %% [markdown]
# **（pythonの関数は基本参照渡しであることに注意） **
#
# ただし、変更されてしまうかどうかは型依存らしい・・・
# http://amacbee.hatenablog.com/entry/2016/12/07/004510

# %%
def Q_learning(s, a, r, s_next, Q, eta, gamma):

    if s_next == 8:  # ゴールした場合
        Q[s, a] = Q[s, a] + eta * (r - Q[s, a])

    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * np.nanmax(Q[s_next,: ]) - Q[s, a])

    return Q

# %% [markdown]
# ## subsandbox

# %%
def reward(s_next):
    if s_next == 8:
        return 1
    else:
        return 0

# %%
s = 0

# %%
Q = np.random.rand(a, b) * theta_0 * 0.1

# %%
epsilon = 0.5

# %%
action = get_action(s, Q , epsilon , pi_0)
print("next action is {} ".format(action))

s_next = get_s_next(0 , action , "meaningless" , "inputs" , "here")
print("next state is {}".format(s_next))
# Out:
# next action is 2
# next state is 3

# %%
gamma
# Out:
# 0.9

# %% [markdown]
# ### （参照渡しなため）Q_learningをQで受けなくても引数がQなだけでQは更新されてしまうことに注意

# %%
Qold = Q.copy()

# %%
Q_learning(s, action, reward(s_next), s_next, Q, eta, gamma)
# Out:
# array([[       nan, 0.08719594, 0.06734074,        nan],
#        [       nan, 0.02627033,        nan, 0.08208485],
#        [       nan,        nan, 0.05900419, 0.09247455],
#        [0.01369089, 0.06638679, 0.04283805,        nan],
#        [       nan,        nan, 0.0982445 , 0.02311464],
#        [0.05701678,        nan,        nan,        nan],
#        [0.09098308,        nan,        nan,        nan],
#        [0.05934305, 0.04537129,        nan,        nan]])

# %%
Q - Qold
# Out:
# array([[        nan,  0.        , -0.00084363,         nan],
#        [        nan,  0.        ,         nan,  0.        ],
#        [        nan,         nan,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,         nan],
#        [        nan,         nan,  0.        ,  0.        ],
#        [ 0.        ,         nan,         nan,         nan],
#        [ 0.        ,         nan,         nan,         nan],
#        [ 0.        ,  0.        ,         nan,         nan]])

# %% [markdown]
# # Q学習で迷路を解く関数の定義、状態と行動の履歴および更新したQを出力

# %%
def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi):
    s = 0  # スタート地点
    a = a_next = get_action(s, Q, epsilon, pi)  # 初期の行動
    s_a_history = [[0, np.nan]]  # エージェントの移動を記録するリスト

    while (1):  # ゴールするまでループ
        a = a_next  # 行動更新

        s_a_history[-1][1] = a
        # 現在の状態（つまり一番最後なのでindex=-1）に行動を代入

        s_next = get_s_next(s, a, Q, epsilon, pi)
        # 次の状態を格納

        s_a_history.append([s_next, np.nan])
        # 次の状態を代入。行動はまだ分からないのでnanにしておく

        # 報酬を与え,　次の行動を求めます
        if s_next == 8:
            r = 1  # ゴールにたどり着いたなら報酬を与える
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            # 次の行動a_nextを求めます。

        # 価値関数を更新
        Q = Q_learning(s, a, r, s_next, Q, eta, gamma)

        # 終了判定
        if s_next == 8:  # ゴール地点なら終了
            break
        else:
            s = s_next

    return [s_a_history, Q]

#
JSBrQkJWVAS1JSBrQkJWVAS1JSBrQkJWVAS1JSBrQkJWVAS1JSBrQkJWVAS1JSBrQkJWVAS1JS\
# BrQkJWVAS1JSXVUXMBwzZsygp6en6jIk1cyCBQtYtGhR1WX82agM6J6eHubPn191GZJqpre3t+oS\
# 1uMUhyQlZUBLUlKjcopjMNtNu5xHl21ddRm1MmvqEhY+cWrb/Y0JS2Fds8SKxoCuBs2109vubjQu\
# BVaXV8+YMJlm87yqixhUbXrQhnPnDXlMDefOG/KYGs6dl/eY1iagJaluDGhJSsqAlqSkDGhJSsqA\
# lqSkDGhJSsqAlqSkDGhJSsqAlqSkDGhJSsqAlqSkDGhJSsqAlqSkDGhJSsqAlqSkDGhJSsqAlqSk\
# DGhJSsqAlqSkDGhJSsqAlqSkDGhJSsqAlqSkDGhJSsqAlqSkDGhJSsqAlqSkDGhJSsqAlqSkuqou\
# oJ6WAZcBtwBLgC2B2cDJwEFAE7gcuB5YAewBnFO00eZbBFwM/Ah4FJgK7Am8C3gpcC3wVeB2YDFw\
# DXBkJZXWywrgBuBe4EmgG5gFHAXsAvyw2LcYmFxs+ytgegW1jk4G9Ij4KPA0cD7wfCKw7wCWF/u/\
# BXwHeDewI3AF8EHgC8AWZRdbA6cDK4FPAzsDjwM3AUuL/SuBFxIfkOdUUF9dXQasAU4CtiEC+/fE\
# 8V4D/BE4GtgeWA1cB3yJ+H8xvoJ6Rx8DuuNWAP8LfAw4sNg2C9i9+HMTuJoIi75e3AXAKcCNwHFl\
# FVoTy4BfAlcBLym2vYAYqfT56+Lr4hLrqrtVwAPAGcCuxbbpxLHv844B73kt8CngMaLjoqE4B91x\
# 3cXrZqIXMdBComfXGiCTgH2Bu0e8uvqZUryuJ3ppKsfE4nUXsHYT39P38+kekYrqyB50x40npi4u\
# BX5AzLvtTfSW96R/2D1twPumYQ9vOLqAzxLH/GvAfsChwAlAb4V11d144PXEyOXXxDTGbGB/YKdB\
# 2q8DvgfsxYbnvtoxoEfEkcSc553APcBvgG8DpxEBAtAY8J7mINu0aU4AXk5MdcwHfgx8jpjX/7sK\
# 66q7/YhOxwPAQ8QFwZ8BryDmnvs8A1xJTIucVnKNo5tTHCNmIjGNcQrwSSJALgeeV+xfOqD9MuxZ\
# PBeTiRUb7yGmO94EfILBp5nUOROI6ysvA/4WOIRYTbOu2P8M8F/E1N6ZxHSUNpUBXZqdiJN1evG6\
# tWXfGqK3vVcFddXVHkRIOC9drpnAs8Sxf4ZYofQIEc5bVVjX6OQUR8c9CXyc6DHPIS6I3E/M1R1A\
# 9CBeTQz5dgR2KP7cTawf1eZZArwVOBXYh1hzfhvwGeDFxIhlKfAwMUqBGJJPJcJkVsn11sVTxIiw\
# l1iRMYk4xvOI6y4TiGV4DxPLIBv0LzOdXOzXUAzojusm5uWuIXoOa4k1oi8B3li0OYlYJ/15+n9R\
# 5aO4Bno4phAh8W9E8K4hAuN1xPJFiIu157a85/zi63uB95VTZu1MIkaFvyAubq8

# %%
# %%bash
# git commit -a -m "again, leavng Q-learning"
# Out:
# [master 50933fb] again, leavng Q-learning
#  2 files changed, 1686 insertions(+), 11371 deletions(-)
#  rewrite program/2_6_Qlearning.ipynb (96%)

# %% [markdown]
# # sandbox

# %%
epsilon
# Out:
# 3.944304526105059e-31

# %%
import sys

# %%
sys.version
# Out:
# '3.5.4 |Anaconda custom (64-bit)| (default, Nov 20 2017, 18:44:38) \n[GCC 7.2.0]'
